# %%
pip install diffusers transformers torch accelerate pillow

# %%
import torch
from diffusers import StableDiffusionPipeline

# Load pre-trained Stable Diffusion model
model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float32
)

pipe = pipe.to("cpu")  # change to "cuda" if GPU available

# Text prompt
prompt = "A futuristic city at sunset, digital art, ultra detailed"

# Generate image
image = pipe(prompt).images[0]

# Save output
image.save("generated_art.png")

print("✅ Image generated and saved as generated_art.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
